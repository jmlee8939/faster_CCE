# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('real_data_2.csv')
data.columns = ['sigma','epsilon','iteration','NMI','ARI']

# %%
data.head(10)
# Out:
#                       sigma   epsilon  iteration     NMI     ARI
# 0                        25  0.000000     3580.0  0.3394  0.5786
# 1                        25  0.000001     1664.0  0.6932  0.8218
# 2                        25  0.000005      335.0  0.7052  0.8341
# 3                        25  0.000010      176.0  0.9754  0.9633
# 4                        25  0.000050       52.0  0.9759  0.9640
# 5                        25  0.000100       34.0  0.9736  0.9611
# 6                        25  0.000500       14.0  0.9550  0.9498
# 7  pen_odd_epsilon(1,3,5,7)       NaN        NaN     NaN     NaN
# 8                        25  0.000000     1625.0  0.1065  0.2759
# 9                        25  0.000001     1051.0  0.2811  0.4299

# %%
data.iloc[[7,15,23,31,39,47],:]
# Out:
#                               sigma  epsilon  iteration  NMI  ARI
# 7          pen_odd_epsilon(1,3,5,7)      NaN        NaN  NaN  NaN
# 15                     iris_epsilon      NaN        NaN  NaN  NaN
# 23                    seeds_epsilon      NaN        NaN  NaN  NaN
# 31  usps_even_data_epsilon(0,2,4,6)      NaN        NaN  NaN  NaN
# 39   usps_odd_data_epsilon(1,3,5,7)      NaN        NaN  NaN  NaN
# 47                wine_data_epsilon      NaN        NaN  NaN  NaN

# %%
pen_even = data.iloc[0:7,:]
pen_odd = data.iloc[8:15,:]
iris = data.iloc[16:23,:]
seeds = data.iloc[24:31,:]
usps_even = data.iloc[32:39,:]
usps_odd = data.iloc[40:47,:]
wine = data.iloc[48:,:]

# %%
## iris

fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Iris',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,2000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(iris.index, iris.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(iris.index,iris['iteration'].values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=12)
#plt.savefig('iris.png')

# %%
## seeds


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Seeds',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,2500))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(seeds.index, seeds.ARI, width = 0.8,
                 color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(seeds.index,seeds['iteration'].values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
#plt.savefig('seeds.png')

# %%
## wine


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Wine',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,1000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(wine.index, wine.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(wine.index,wine.iteration.values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
plt.savefig('wine.png')

# %%
## pen_odd


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Penbased(1,3,5,7)',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,2000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(pen_odd.index, pen_odd.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(pen_odd.index,pen_odd.iteration.values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
plt.savefig('pen_odd.png')

# %%
    ## pen_even


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Penbased(0,2,4,8)',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,4000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(pen_even.index, pen_even.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(pen_even.index,pen_even.iteration.values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
plt.savefig('pen_even.png')

# %%
## usps_odd


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Usps(1,3,5,7)',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,1000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(usps_odd.index, usps_odd.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(usps_odd.index,usps_odd.iteration.values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
plt.savefig('usps_odd.png')

# %%
## usps_even


fig, ax1 = plt.subplots(figsize=(10,5))
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=12)
plt.title('Usps(0,2,4,8)',fontsize=25)
plt.grid(color='black', linestyle='--', linewidth=0.5, axis='y')
ax2 = ax1.twinx()
ax1.set_ylim((0,1))
ax1.set_xlabel('epsilon', fontsize=20)
ax1.set_xticklabels(['','0','1e-6',
                     '5e-6','1e-5',
                     '5e-5','1e-4',
                     '5e-4'])
ax1.set_ylabel('ARI',fontsize=20)
ax2.set_ylim((0,3000))
ax2.set_ylabel('Iteration',fontsize=20)
graph1 = ax1.bar(usps_even.index, usps_even.ARI, width = 0.8,color = ['gray'], edgecolor='black')
patterns = ('/', '', '', '', '', '', '')
labels = ('ARI - CCE', 'ARI - faster CCE')
for bar, pattern, label in zip(graph1, patterns, labels):
    bar.set_hatch(pattern)
    bar.set_label(label)
graph2 = ax2.plot(usps_even.index,usps_even.iteration.values, color='red',
         linestyle='-', marker='o', linewidth=2.0, markersize=10, label='Iteration',
                   alpha=0.8)
#fig.legend(bbox_to_anchor = (0.9,0.88) , fontsize=15)
plt.savefig('usps_even.png')
